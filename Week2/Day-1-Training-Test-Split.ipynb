# %%
from sklearn.datasets import load_boston
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from sklearn.model_selection import train_test_split

# %%
bundle = load_boston()

# %%
X= bundle.data
y=bundle.target

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %% [markdown]
# ## Training on the entire dataset

# %%
def compute_model_values(X,y):
    model =LinearRegression()
    model.fit(X,y)
    y_pred=model.predict(X)
    rmse=mean_squared_error(y,y_pred)**0.5
    r2=r2_score(y,y_pred)
    print(model.score(X,y))
    return {"r2":r2,"rmse":rmse,
            "intercept":model.intercept_,
            "coeff":model.coef_
            
           }

# %%
compute_model_values(X,y)
# Out:
# 0.7406426641094095
# {'r2': 0.7406426641094095,
#  'rmse': 4.679191295697281,
#  'intercept': 36.459488385089855,
#  'coeff': array([-1.08011358e-01,  4.64204584e-02,  2.05586264e-02,  2.68673382e+00,
#         -1.77666112e+01,  3.80986521e+00,  6.92224640e-04, -1.47556685e+00,
#          3.06049479e-01, -1.23345939e-02, -9.52747232e-01,  9.31168327e-03,
#         -5.24758378e-01])}

# %% [markdown]
# ## Train test split

# %%
len(train_test_split(X,y))
# Out:
# 4

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8)

# %%
X_train.shape
# Out:
# (404, 13)

# %%
X_test.shape
# Out:
# (102, 13)

# %%
X_train.shape[0]/X.shape[0]
# Out:
# 0.7984189723320159

# %%
X_test.shape[0]/X.shape[0]
# Out:
# 0.2015810276679842

# %%
def compute_model_train_test_values(X,y,test_size=0.25):
    X_train,X_test,y_train,y_test=train_test_split(X,y,
                                                   test_size=test_size)
    model =LinearRegression()
    model.fit(X_train,y_train)
    y_pred_train=model.predict(X_train)
    rmse_train=mean_squared_error(y_train,y_pred_train)**0.5
    r2_train=r2_score(y_train,y_pred_train)
    
    y_pred_test=model.predict(X_test)
    rmse_test=mean_squared_error(y_test,y_pred_test)**0.5
    r2_test=r2_score(y_test,y_pred_test)
    return {
            "testing accuracy":r2_test,
            "training accuracy":r2_train,
            "rmse_test":rmse_test,
            "rmse_train":rmse_train,
            "intercept":model.intercept_,
            "coeff":model.coef_
           }

# %%
compute_model_train_test_values(X,y)
# Out:
# {'testing accuracy': 0.7296976800181776,
#  'training accuracy': 0.7348000933372134,
#  'rmse_test': 5.520632978694289,
#  'rmse_train': 4.454430671106973,
#  'intercept': 38.33636446723138,
#  'coeff': array([-7.68376475e-02,  4.78205206e-02,  5.45643206e-02,  3.35940788e-01,
#         -1.61679632e+01,  3.51581344e+00,  3.98174446e-03, -1.30353548e+00,
#          2.97512465e-01, -1.45091419e-02, -1.00962487e+00,  8.06980688e-03,
#         -5.10089267e-01])}

# %%
Overfitting and underfitting
